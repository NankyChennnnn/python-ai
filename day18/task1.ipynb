# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.8401, 0.0199, 0.7185],
#         [0.7020, 0.3267, 0.6967],
#         [0.1738, 0.0415, 0.4812],
#         [0.1301, 0.8093, 0.4515],
#         [0.0202, 0.1112, 0.2956]])

# %%
# 验证当前PyTorch是否支持CPU计算
x = torch.tensor([1.0, 2.0])
print(x.device)  # 输出应为 cpu
# Out:
# cpu
