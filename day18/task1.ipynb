# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6417, 0.1860, 0.6759],
#         [0.1366, 0.7201, 0.8157],
#         [0.6596, 0.7654, 0.5320],
#         [0.8802, 0.1708, 0.1745],
#         [0.9164, 0.1386, 0.7787]])

# %%
# 验证当前PyTorch是否支持CPU计算
x = torch.tensor([1.0, 2.0])
print(x.device)  # 输出应为 cpu
# Out:
# cpu
