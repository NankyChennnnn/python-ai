# %% [markdown]
# ### 逻辑回归原理

# %% [markdown]
# - 逻辑回归 = 线性回归 + sigmoid 函数
# - 本质就是通过模型，训练出一条由直线表示的决策边界，是一种线性分类器，通常用于二分类问题

# %% [markdown]
# ### L1 正则化

# %% [markdown]
# - 特征筛选
# - 倾向于将部分参数直接压缩为 0，因此能产生**稀疏模型**。
# - 加入参数绝对值之和

# %% [markdown]
# ### L2 正则化

# %% [markdown]
# - 平滑函数
# - 加入参数平方和
