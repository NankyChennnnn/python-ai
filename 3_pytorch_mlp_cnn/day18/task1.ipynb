# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.7210, 0.2283, 0.3833],
#         [0.8341, 0.3573, 0.8429],
#         [0.2281, 0.8983, 0.5100],
#         [0.5031, 0.2643, 0.6496],
#         [0.1400, 0.4621, 0.4439]])

# %%
# 验证当前PyTorch是否支持CPU计算
x = torch.tensor([1.0, 2.0])
print(x.device)  # 输出应为 cpu
# Out:
# cpu
