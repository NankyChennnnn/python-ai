# %% [markdown]
# # 归一化

# %%
import numpy as np

# 用 numpy array 生成数组
arr = np.array([[1,200],[2,300],[3,400]])
print("原始数组：\n", arr)

# 归一化处理（按每列进行0-1归一化）
arr_min = arr.min(axis=0)
arr_max = arr.max(axis=0)
arr_normalized = (arr - arr_min) / (arr_max - arr_min)
print("归一化后的数组：\n", arr_normalized)
# Out:
# 原始数组：
#  [[  1 200]
#  [  2 300]
#  [  3 400]]
# 归一化后的数组：
#  [[0.  0. ]
#  [0.5 0.5]
#  [1.  1. ]]

# %% [markdown]
# # 标准化

# %%
# 标准化处理（按每列做z-score标准化，即减均值除以标准差）
arr_mean = arr.mean(axis=0)
arr_std = arr.std(axis=0)
arr_standardized = (arr - arr_mean) / arr_std
print("标准化后的数组：\n", arr_standardized)
# Out:
# 标准化后的数组：
#  [[-1.22474487 -1.22474487]
#  [ 0.          0.        ]
#  [ 1.22474487  1.22474487]]

# %% [markdown]
# # 缺失值处理

# %%
from sklearn.impute import SimpleImputer

data = np.array([[1, np.nan], [2, 300], [np.nan, 400]])
print("原始数组：\n", data)
# strategy可以为mean、median、most_frequent、constant
imputer = SimpleImputer(strategy='mean')
data_imputed = imputer.fit_transform(data)
print("缺失值处理后的数组：\n", data_imputed)
# Out:
# 原始数组：
#  [[  1.  nan]
#  [  2. 300.]
#  [ nan 400.]]
# 缺失值处理后的数组：
#  [[  1.  350. ]
#  [  2.  300. ]
#  [  1.5 400. ]]
